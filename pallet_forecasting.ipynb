# %%
# !pip install gradio==4.0.2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 649.6 kB/s eta 0:00:00
# ...
# WARNING: typer 0.12.3 does not provide the extra 'all'
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.3/25.3 MB 28.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.7/302.7 kB 16.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 10.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 8.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 4.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tomlkit
# ...

# %%
import gradio as gr
gr.__version__
# Out:
# '4.0.2'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def send_msg(msg):
  return msg

iface = gr.Interface(fn=send_msg, inputs='textbox', outputs='textbox')
iface.launch()
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# IMPORTANT: You are using gradio version 4.0.2, however version 4.29.0 is available, please upgrade.
# --------
# Running on public URL: https://b99702a2640fb5356f.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://b99702a2640fb5356f.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr
import pandas as pd
import pickle
from datetime import datetime

model = pickle.load(open('/content/drive/MyDrive/Colab Notebooks/model.pkl', 'rb'))

def predict(input_date):

    # Converting input date to datetime
    current_date = pd.to_datetime(input_date)

    # DataFrame for the input date
    date_df = pd.DataFrame({"Date": [current_date]})

    # Predict using the loaded ARIMA model ( Auto Regressive Integrated Moving Average )
    forecast = model.predict(start=len(date_df), end=len(date_df) + 6)  # Forecast for the next 7 days

    return forecast.values.flatten().tolist()

iface = gr.Interface(fn=predict, inputs="textbox", outputs="textbox")
iface.launch()
# Out:
# IMPORTANT: You are using gradio version 4.0.2, however version 4.29.0 is available, please upgrade.
# --------
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://4c6b91f466c03ef4b8.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://4c6b91f466c03ef4b8.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# !pip install evidently==0.2.8
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 70.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 78.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.5.3
#     Uninstalling pydantic-2.5.3:
#       Successfully uninstalled pydantic-2.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires kaleido, which is not installed.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# gradio 4.0.2 requires pydantic>=2.0, but you have pydantic 1.10.13 which is incompatible.
# ...

# %%
import evidently
print(evidently.__version__)
# Out:
# 0.2.8

# %%
from evidently.dashboard import Dashboard

# %%
import gradio as gr
import pandas as pd
import pickle
from datetime import datetime
from evidently.report import Report
from evidently.metric_preset import DataDriftPreset, TargetDriftPreset, DataQualityPreset
# Load the ARIMA model
model = pickle.load(open('model.pkl', 'rb'))

def predict(input_date):
    # Convert input date to datetime
    current_date = pd.to_datetime(input_date)

    # Create a DataFrame with the input date
    date_df = pd.DataFrame({"Date": [current_date]})

    # Predict using the loaded ARIMA model
    forecast = model.predict(start=len(date_df), end=len(date_df) + 6)

    # Save the output to a file
    save_file(current_date, forecast)

    # Monitor the model performance
    monitor_performance(current_date, forecast)

    forecast_str = forecast.to_string(index=False)

    return forecast_str

def save_file(f_date, f_data):
    forecast_df = pd.DataFrame({'Date': f_date, 'Forecast': f_data})
    forecast_df.to_csv('forecast_output.csv', index=False)

def monitor_performance(date, forecast):
    # Load the reference dataset
    reference = pd.read_csv('sample.csv')
    reference['Date'] = pd.to_datetime(reference['Date'])

    # Create a DataFrame with the input date
    date_df = pd.DataFrame({"Date": [date]})

    # Evaluate model performance
    evaluation_result = evaluate_model(reference, date_df, forecast)

    # Log the evaluation result or take necessary actions
    log_evaluation_result(evaluation_result)

def evaluate_model(reference, date_df, forecast):
    # Calculate metrics for regression performance
    reg_metrics = RegressionPerformanceTab(reference_data=reference, current_data=date_df)

    # Extract and return evaluation result
    evaluation_result = reg_metrics.get_metrics_data()
    return evaluation_result

def log_evaluation_result(evaluation_result):
    # Log the evaluation result or take necessary actions
    print("Evaluation Result:", evaluation_result)

# Launch Gradio interface
iface = gr.Interface(fn=predict, inputs="textbox", outputs="textbox")
iface.launch()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-a1e75a871dea> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 import gradio as gr
#       3 import pickle
#       4 from datetime import datetime
#       5 # from evidently.dashboard import Dashboard
#
# /usr/local/lib/python3.10/dist-packages/gradio/__init__.py in <module>
#       1 import json
#       2
# ----> 3 import gradio._simple_templates
#       4 import gradio.components as components
#       5 import gradio.image_utils
#
# /usr/local/lib/python3.10/dist-packages/gradio/_simple_templates/__init__.py in <module>
# ----> 1 from .simpledropdown import SimpleDropdown
#       2 from .simpletextbox import SimpleTextbox
#       3
#       4 __all__ = ["SimpleDropdown", "SimpleTextbox"]
#
# /usr/local/lib/python3.10/dist-packages/gradio/_simple_templates/simpledropdown.py in <module>
# ...

# %%
from evidently.test_suite import TestSuite
from evidently.tests import *
from evidently.metrics import *
from evidently.report import Report
from evidently.metric_preset import  TargetDriftPreset

# %%
import pandas as pd

# Read the Excel file into a DataFrame
excel_file = pd.read_excel('sample_data.xlsx')

# Replace 'your_output_file.csv' with the desired name for the CSV file
csv_file = 'sample.csv'

# Save the DataFrame to a CSV file
excel_file.to_csv(csv_file, index=False)

# %%
import evidently
from evidently.report import Report
from evidently.metric_preset import DataDriftPreset, TargetDriftPreset, DataQualityPreset
import pickle
import pandas as pd

# Load the reference dataset
reference = pd.read_csv('sample.csv')
# reference
reference['Date'] = pd.to_datetime(reference['Date'])

# Load the current dataset
current = pd.read_csv('forecast_output.csv')
current['Date'] = pd.to_datetime(current['Date'])

# Create a ColumnMapping object
column_mapping = evidently.ColumnMapping()
column_mapping.datetime = 'Date'
column_mapping.numerical_features = ['Quantity']

data_quality_report = Report(metrics=[DataQualityPreset()])

# Pass the column_mapping object to the report
data_quality_report.run(current_data=current, reference_data=reference, column_mapping=column_mapping)
data_quality_report

data_quality_report.save_html("file1.html")
data_quality_report.save("snapshot1.json")
print('Done')
# Out:
# Done

# %%
from evidently.dashboard import Dashboard
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-843b8e47a633> in <cell line: 1>()
# ----> 1 from evidently.dashboard import Dashboard
#
# /usr/local/lib/python3.10/dist-packages/evidently/dashboard/__init__.py in <module>
#       4 import warnings
#       5
# ----> 6 from .dashboard import Dashboard
#       7
#       8 warnings.warn("dashboards are deprecated, use metrics instead")
#
# /usr/local/lib/python3.10/dist-packages/evidently/dashboard/dashboard.py in <module>
#      15 import pandas
#      16
# ---> 17 from evidently.dashboard.tabs.base_tab import Tab
#      18 from evidently.model.dashboard import DashboardInfo
#      19 from evidently.model.widget import AdditionalGraphInfo
#
# /usr/local/lib/python3.10/dist-packages/evidently/dashboard/tabs/__init__.py in <module>
#       2 # coding: utf-8
#       3
# ...

# %%
import gradio as gr
import pandas as pd
from datetime import datetime
import pickle
from evidently.dashboard import Dashboard
from evidently.tabs import RegressionPerformanceTab

# Load the ARIMA model
model = pickle.load(open('/content/drive/MyDrive/Colab Notebooks/model.pkl', 'rb'))

def predict(input_date):
    # Convert input date to datetime
    current_date = pd.to_datetime(input_date)

    # Create a DataFrame with the input date
    date_df = pd.DataFrame({"Date": [current_date]})

    # Predict using the loaded ARIMA model
    forecast = model.predict(start=len(date_df), end=len(date_df) + 6)

    # Save the output to a file
    save_file(current_date, forecast)

    # Monitor the model performance
    monitor_performance(current_date, forecast)

    forecast_str = forecast.to_string(index=False)

    return forecast_str

def save_file(f_date, f_data):
    forecast_df = pd.DataFrame({'Date': f_date, 'Forecast': f_data})
    forecast_df.to_csv('forecast_output.csv', index=False)

def monitor_performance(date, forecast):
    # Load the reference dataset
    xl_file = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/sample_data.xlsx')
    xl_file.to_csv('sample.csv', index=False)
    reference = pd.read_csv('sample.csv')
    reference['Date'] = pd.to_datetime(reference['Date'])

    # Create a DataFrame with the input date
    date_df = pd.DataFrame({"Date": [date]})

    current = pd.read_csv('forecast_output.csv')
    current['Date'] = pd.to_datetime(current['Date'])

    # Evaluate model performance
    evaluation_result = evaluate_model(reference, current)

    # Log the evaluation result or take necessary actions
    log_evaluation_result(evaluation_result)

def evaluate_model(reference, current):
    # Create a ColumnMapping object
    column_mapping = evidently.ColumnMapping()
    column_mapping.datetime = 'Date'
    column_mapping.numerical_features = ['Quantity']

    # Generate a report for regression performance
    report = Dashboard(tabs=[RegressionPerformanceTab])
    report.calculate(reference_data = reference, current_data = current, column_mapping = column_mapping)

    # Extract and return evaluation result
    evaluation_result = report.get_metrics_data()
    return evaluation_result

def log_evaluation_result(evaluation_result):
    # Log the evaluation result or take necessary actions
    print("Evaluation Result:", evaluation_result)

# Launch Gradio interface
iface = gr.Interface(fn=predict, inputs="textbox", outputs="textbox")
iface.launch(debug=True)
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://438e49ac2e3d54540f.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://438e49ac2e3d54540f.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/gradio/queueing.py", line 427, in call_prediction
#     output = await route_utils.call_process_api(
# ...

# %%
import gradio as gr
import pandas as pd
import pickle
from evidently.dashboard import Dashboard
from evidently.tabs import RegressionPerformanceTab

# Load the ARIMA model
model = pickle.load(open('/content/drive/MyDrive/Colab Notebooks/model.pkl', 'rb'))

def predict(input_date):
    # Convert input date to datetime
    current_date = pd.to_datetime(input_date)

    # Create a DataFrame with the input date
    date_df = pd.DataFrame({"Date": [current_date]})

    # Predict using the loaded ARIMA model
    forecast = model.predict(start=len(date_df), end=len(date_df) + 6)

    # Save the output to a file
    save_file(current_date, forecast)

    # Monitor the model performance
    monitor_performance(current_date, forecast)

    forecast_str = forecast.to_string(index=False)

    return forecast_str

def save_file(f_date, f_data):
    forecast_df = pd.DataFrame({'Date': f_date, 'Forecast': f_data})
    forecast_df.to_csv('forecast_output.csv', index=False)

def monitor_performance(date, forecast):
    # Load the reference dataset
    xl_file = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/sample_data.xlsx')
    xl_file.to_csv('sample.csv', index=False)
    reference = pd.read_csv('sample.csv')
    reference['Date'] = pd.to_datetime(reference['Date'])

    # Create a DataFrame with the input date
    date_df = pd.DataFrame({"Date": [date]})

    current = pd.read_csv('forecast_output.csv')
    current['Date'] = pd.to_datetime(current['Date'])

    # Evaluate model performance
    evaluation_result = evaluate_model(reference, current)

    # Log the evaluation result or take necessary actions
    log_evaluation_result(evaluation_result)

def evaluate_model(reference, current):
    # Create a ColumnMapping object
    column_mapping = evidently.ColumnMapping()
    column_mapping.datetime = 'Date'
    column_mapping.numerical_features = ['Quantity']

    # Generate a report for regression performance
    report = Dashboard(tabs=[RegressionPerformanceTab])
    report.calculate(reference_data=reference, current_data=current, column_mapping=column_mapping)

    # Extract and return evaluation result
    evaluation_result = report.get_metrics_data()
    return evaluation_result

def log_evaluation_result(evaluation_result):
    # Log the evaluation result or take necessary actions
    print("Evaluation Result:", evaluation_result)

# Launch Gradio interface
iface = gr.Interface(fn=predict, inputs="textbox", outputs="textbox")
iface.launch(debug=True)
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://4a36613e34f2ebfe34.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://4a36613e34f2ebfe34.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/gradio/queueing.py", line 427, in call_prediction
#     output = await route_utils.call_process_api(
# ...
